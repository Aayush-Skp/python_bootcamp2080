# %% [markdown]
# ## Agendas { Working with numpy and Pandas }
# - Download existing dataset -> platform: kaggle
# - Perform some operations on the dataset   ::-> Why?
# - create some visualization

# %% [markdown]
# ### Working with dataset
# - 1:   import numpy and panda
# - 2:   read the dataset in csv format
# - 3:   explore the dataset
# - 3.1: print first five rows of the dataset
# - 3.2: print first end rows of dataset
# - 3.3: print last 5 rows of dataset
# - 3.4: Describe your dataset
# - 3.5: how to find the total number of columns in every row with null values
# - 3.6: print number of rows in columns, type of data and number of missing values. .info() & .describe() can be used to describe the basic information about dataset

# %%
#importing both the libs numpy and pandas
import numpy as np
import pandas as pd

# %%
my_data = pd.read_csv("products_data.csv")
my_data
# Out:
#                                        Name Current Price Previous Price  \
# 0                          English Cucumber          1.99           1.99
# 1                               Green Onion          1.29           1.29
# 2           Bi-Colour Corn, Corn on the Cob          0.99           0.99
# 3                     Romaine Heart, 3 Pack          6.00           6.00
# 4                           Red Peppers              2.38           2.38
# ...                                     ...           ...            ...
# 17254                    Beef Sausage Rolls          8.79           8.79
# 17255  Creamy Chicken and Vegetable Pot Pie          8.00           8.00
# 17256                     Quiche Florentine          8.00           8.00
# 17257                             Green Tea          2.29           2.29
# 17258             Hard-boiled Eggs, Omega-3          1.29           1.29
#
#        Price Per Each          Category      Product ID  \
# ...

# %%
print(my_data.head(10)) #Accessing top 10 rows instead of deafult 5 rows
# Out:
#                               Name Current Price Previous Price  \
# 0                 English Cucumber          1.99           1.99
# 1                      Green Onion          1.29           1.29
# 2  Bi-Colour Corn, Corn on the Cob          0.99           0.99
# 3            Romaine Heart, 3 Pack          6.00           6.00
# 4                  Red Peppers              2.38           2.38
# 5                    Yellow Onions          2.99           2.99
# 6                    Celery Stalks          3.49           3.49
# 7                  Lettuce Iceberg          3.99           3.99
# 8                         Broccoli          3.99           3.99
# 9                        Red Onion          2.03           2.03
#
#   Price Per Each          Category      Product ID  \
# 0      $1.99/1ea  Fresh Vegetables  20070132001_EA
# 1      $1.29/1ea  Fresh Vegetables  20107500001_EA
# 2      $0.99/1ea  Fresh Vegetables  20131170001_EA
# 3      $2.00/1ea  Fresh Vegetables  20067389001_EA
# ...

# %%
print(my_data.tail(7)) #Accessing bottom 7 rows instead of deafult 5 rows
# Out:
#                                        Name Current Price Previous Price  \
# 17252                  Margherita Flatbread          7.00           7.00
# 17253                      Veggie Flatbread          7.00           7.00
# 17254                    Beef Sausage Rolls          8.79           8.79
# 17255  Creamy Chicken and Vegetable Pot Pie          8.00           8.00
# 17256                     Quiche Florentine          8.00           8.00
# 17257                             Green Tea          2.29           2.29
# 17258             Hard-boiled Eggs, Omega-3          1.29           1.29
#
#        Price Per Each        Category   Product ID  \
# 17252      $1.41/100g           Pizza  21333841_EA
# 17253      $1.40/100g           Pizza  21333794_EA
# 17254      $1.40/100g  Quiches & Pies  21116219_EA
# 17255  $1,600.00/100g  Quiches & Pies  21401776_EA
# 17256      $1.60/100g  Quiches & Pies  21401761_EA
# 17257     $0.48/100ml       Beverages  20923222_EA
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"> <b> When you don't have columns names </b><br>
# names = ["length","breadth","height"]           //Making a list with all the columns names
# <br>my_dataset.colums = names                       // Assign in dataset columns
# <br>Excercise: If my columns names are greater than of my dataset, what will be the error? </div>

# %%
my_data.info()  #For getting basic info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17259 entries, 0 to 17258
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            17259 non-null  object
#  1   Current Price   17259 non-null  object
#  2   Previous Price  17259 non-null  object
#  3   Price Per Each  17259 non-null  object
#  4   Category        17259 non-null  object
#  5   Product ID      17259 non-null  object
#  6   Product URL     17259 non-null  object
#  7   Amount          17259 non-null  object
#  8   Units           17259 non-null  object
# dtypes: object(9)
# memory usage: 1.2+ MB

# %%
my_data.describe()   #descriptive statistics of a DataFrame
# Out:
#              Name Current Price Previous Price Price Per Each        Category  \
# count       17259         17259          17259          17259           17259
# unique      13147           817            829           1527             118
# top     Soy Sauce          4.99           4.99     $1.50/100g  Chips & Snacks
# freq           17           823            823            189             951
#
#          Product ID                                        Product URL Amount  \
# count         17259                                              17259  17259
# unique        14423                                              14423    982
# top     21190251_EA  https://www.realcanadiansuperstore.ca/apples-c...      1
# freq             14                                                 14   1513
#
#         Units
# count   17259
# unique     12
# top         g
# freq    10792

# %%
#the drop() function is used to remove specified rows or columns from a DataFrame
my_data.drop(["Product URL","Category"], axis=1).head()
# Out:
#                               Name Current Price Previous Price  \
# 0                 English Cucumber          1.99           1.99
# 1                      Green Onion          1.29           1.29
# 2  Bi-Colour Corn, Corn on the Cob          0.99           0.99
# 3            Romaine Heart, 3 Pack          6.00           6.00
# 4                  Red Peppers              2.38           2.38
#
#   Price Per Each      Product ID Amount  Units
# 0      $1.99/1ea  20070132001_EA      1     ea
# 1      $1.29/1ea  20107500001_EA      1  bunch
# 2      $0.99/1ea  20131170001_EA      1     ea
# 3      $2.00/1ea  20067389001_EA      3   pack
# 4      $9.90/1kg  20007535001_KG      1     ea

# %%
my_data.isnull()  # TO find the null data in any dataframe
# Out:
#         Name  Current Price  Previous Price  Price Per Each  Category  \
# 0      False          False           False           False     False
# 1      False          False           False           False     False
# 2      False          False           False           False     False
# 3      False          False           False           False     False
# 4      False          False           False           False     False
# ...      ...            ...             ...             ...       ...
# 17254  False          False           False           False     False
# 17255  False          False           False           False     False
# 17256  False          False           False           False     False
# 17257  False          False           False           False     False
# 17258  False          False           False           False     False
#
#        Product ID  Product URL  Amount  Units
# 0           False        False   False  False
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Why to delete rows? </b><br>
#     One answer can be:  to remove biasing from the dataset while training to ML Model </div>

# %%
#Way to remove the rows
my_data.drop(range(1, 10000), axis=0)
# Out:
#                                                     Name Current Price  \
# 0                                       English Cucumber          1.99
# 10000                            Milk Chocolate Caramels          2.99
# 10001                 LINDOR Milk Chocolate Truffles Bag          8.99
# 10002                            COOKIES 'N' CRÈME candy          5.49
# 10003  TWIX Caramel Cookie Chocolate Candy Bar, King ...          1.79
# ...                                                  ...           ...
# 17254                                 Beef Sausage Rolls          8.79
# 17255               Creamy Chicken and Vegetable Pot Pie          8.00
# 17256                                  Quiche Florentine          8.00
# 17257                                          Green Tea          2.29
# 17258                          Hard-boiled Eggs, Omega-3          1.29
#
#       Previous Price  Price Per Each           Category      Product ID  \
# ...

# %%
my_data.isnull().sum() #Shows the total nulls in all columns lof the dataset
# Out:
# Name              0
# Current Price     0
# Previous Price    0
# Price Per Each    0
# Category          0
# Product ID        0
# Product URL       0
# Amount            0
# Units             0
# dtype: int64

# %%
my_data['Amount'] = pd.to_numeric(my_data['Amount'], errors='coerce')

# Calculate mean, skipping NaN values
mean_previous_price = my_data['Amount'].mean(skipna=True) # To find mean of specific column

print(mean_previous_price)
# Out:
# 295.07222045801524

# %%
#my_data.groupby(['Category']).mean

# %%
my_data['Previous Price'].max()
# Out:
# '9.99'

# %%
my_data['Current Price'].min()
# Out:
# ' 0.18'

# %% [markdown]
# ### Assignment: to find the sum of column element

# %% [markdown]
# ### My learning from operations in dataset
# - 1. I learned how to seek for the dataset from the internet and import in the notebook for the further operation.
# - 2. leaned to get the basic info about not-null count and Datatype from the info() function and Descriptive statistics of dataset from describe() function
# - 3. ways to observe the specific numbers of top columns and rows
# - 4. ways to remove the specific number of rows and columns
# - 5. to remove the biasing, we can remove the rows

# %% [markdown]
# ## Working with matplotlib

# %%
pip install matplotlib #Installing Matplotlib

# %%
import matplotlib.pyplot as plt #importing matplotlib

# %%
plt.hist(my_data['Current Price'],bins= 10, range=(0,10))
plt.title('Current Price')

# %%
plt.scatter(my_data['Current Price'], my_data['Previous Price'])
plt.xlabel('Current')
plt.ylabel('Previous')

# %% [markdown]
# ### My insight from the observing the dataset
# -
